# %%
from MainService import MainService

# %%
m = MainService()
m.mockUpdateAllData()
# Out:
# Getting Mock data...
# ---------------------------------------------------------------------------
# Data Collection Succesful.
# TimeSeries dictionary has 342 entries.
# Initializing correlator with updated data

# %%
m.queryNames("wheat")
# Out:
# {'Bread whole wheat pan per lb. (453.6 gm) in U.S. city average average price not seasonally adjusted'}

# %%
search = 'Bread whole wheat pan per lb. (453.6 gm) in U.S. city average average price not seasonally adjusted'
series = m.findFiveHighestCorrelated(search, varied_ind = False)

# %%
Ids = []
for Id in series:
    Ids.append(Id[0])

m.plotTimeSeries(Ids)
