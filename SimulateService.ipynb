# %%
from MainService import MainService

# %%
m = MainService()
m.updateAllData()
# Out:
# Updating all data...
# https://download.bls.gov/pub/time.series/wp
# File 1/44: https://download.bls.gov/pub/time.series/
# File 2/44: https://download.bls.gov/pub/time.series/wp/wp.contacts
# File 3/44: https://download.bls.gov/pub/time.series/wp/wp.data.0.Current
# File 4/44: https://download.bls.gov/pub/time.series/wp/wp.data.1.AllCommodities
# File 5/44: https://download.bls.gov/pub/time.series/wp/wp.data.10.Pulp
# File 6/44: https://download.bls.gov/pub/time.series/wp/wp.data.11a.Metals10-103
# File 7/44: https://download.bls.gov/pub/time.series/wp/wp.data.11b.Metals104-109
# File 8/44: https://download.bls.gov/pub/time.series/wp/wp.data.12a.Machinery11-113
# File 9/44: https://download.bls.gov/pub/time.series/wp/wp.data.12b.Machinery114-116
# File 10/44: https://download.bls.gov/pub/time.series/wp/wp.data.12c.Machinery117-119
# File 11/44: https://download.bls.gov/pub/time.series/wp/wp.data.12i.MachineryInputs
# ...

# %%
m.queryNames("soybean")
# Out:
# {'PPI Commodity data for Chemicals and allied products-Crude soybean oil degummed made from soybeans crushed in the same establishment not seasonally adjusted',
#  'PPI Commodity data for Chemicals and allied products-Soybean oil all other types not seasonally adjusted',
#  'PPI Commodity data for Chemicals and allied products-Soybean oil processed for inedible purposes not seasonally adjusted',
#  'PPI Commodity data for Farm products-Soybeans not seasonally adjusted',
#  'PPI Commodity data for Processed foods and feeds-Other soybean products including isolates and concentrates not seasonally adjusted',
#  'PPI Commodity data for Processed foods and feeds-Soybean cake and meal not seasonally adjusted',
#  'PPI Commodity data for Processed foods and feeds-Soybean cake meal and other byproducts not seasonally adjusted',
#  'PPI industry data for Soybean and other oilseed processing not seasonally adjusted',
# ...

# %%
search = 'PPI industry data for Soybean and other oilseed processing-Other soybean products including isolates and concentrates not seasonally adjusted'
series = m.findFiveHighestCorrelated(search, varied_ind = False)

# %%
Ids = []
for Id in series:
    print(Id)
    Ids.append(Id[0])
m.plotTimeSeries(Ids)
# Out:
# ('PCU311119311119H', 0.5661466641222259)
# ('WPU02930117', 0.5647828505564357)
# ('WPU02940317', 0.5191888317076758)
# ('PCU311221311221A', 0.517743110740177)
# ('WPU02930115', 0.4987562279646035)
