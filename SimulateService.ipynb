# %%
from MainService import MainService

# %%
m = MainService()
m.mockUpdateAllData()
# Out:
# Getting Mock data...
# ---------------------------------------------------------------------------
# Data Collection Succesful.
# TimeSeries dictionary has 9328 entries.
# Initializing correlator with updated data

# %%
m.queryNames("import")
# Out:
# {'PPI Commodity data for Net inputs to 325510 paint and coating manufacturing excl. capital investment labor and imports not seasonally adjusted',
#  'PPI Commodity data for Net inputs to 336111 automobile manufacturing excluding capital investment labor and imports not seasonally adjusted',
#  'PPI Commodity data for Net inputs to 621A00 offices of health practitioners excl. capital investment labor and imports not seasonally adjusted'}

# %%
search = 'PPI Commodity data for Net inputs to 621A00 offices of health practitioners excl. capital investment labor and imports not seasonally adjusted'
series = m.findFiveHighestCorrelated(search, varied_ind = True)

# %%
Ids = []
for Id in series:
    Ids.append(Id[0])

m.plotTimeSeries(Ids)
